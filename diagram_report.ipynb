# %%
import pandas as pd

# Создаём DataFrame с данными по 5 вопросам и их кластерам
data = {
    'Вопрос': [
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?', 
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?',
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?',
        
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?', 
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?',
        
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?', 
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?',
        
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?', 
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?',
        
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?', 
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?'
    ],
    'Ответ': [
        'Хорошо', 'Отлично', 'Плохо', 'Ужасно', 'Нейтрально', 'Не знаю',  # Вопрос 1
        'Дружный', 'Конфликтный', 'Поддерживающий', 'Не знаю',  # Вопрос 2
        'Хорошие перспективы', 'Нет перспектив', 'Не знаю', 'Средние возможности',  # Вопрос 3
        'Удобный', 'Неудобный', 'Гибкий', 'Среднеудобный',  # Вопрос 4
        'Поддержка есть', 'Нет поддержки', 'Слабая поддержка', 'Не знаю'  # Вопрос 5
    ],
    'Количество': [
        50, 30, 10, 5, 20, 5,  # Вопрос 1
        40, 10, 30, 5,  # Вопрос 2
        35, 15, 10, 20,  # Вопрос 3
        45, 10, 30, 15,  # Вопрос 4
        25, 20, 15, 10  # Вопрос 5
    ],
    'Кластер': [
        1, 1, 2, 2, 3, 3,  # Вопрос 1
        1, 2, 1, 3,  # Вопрос 2
        1, 2, 3, 1,  # Вопрос 3
        1, 2, 1, 3,  # Вопрос 4
        1, 2, 3, 3  # Вопрос 5
    ]
}

df = pd.DataFrame(data)

# Отобразим получившийся DataFrame
print(df)
# Out:
#                                               Вопрос                Ответ
# 0                  Как вы оцениваете условия работы?               Хорошо  \
# 1                  Как вы оцениваете условия работы?              Отлично
# 2                  Как вы оцениваете условия работы?                Плохо
# 3                  Как вы оцениваете условия работы?               Ужасно
# 4                  Как вы оцениваете условия работы?           Нейтрально
# 5                  Как вы оцениваете условия работы?              Не знаю
# 6                       Как вы оцениваете коллектив?              Дружный
# 7                       Как вы оцениваете коллектив?          Конфликтный
# 8                       Как вы оцениваете коллектив?       Поддерживающий
# 9                       Как вы оцениваете коллектив?              Не знаю
# 10                 Как оцениваете возможности роста?  Хорошие перспективы
# 11                 Как оцениваете возможности роста?       Нет перспектив
# ...

# %%
import pandas as pd
df = pd.read_csv('df_proc.csv')
df
# Out:
#     Unnamed: 0                                             Вопрос
# 0            0  Комментарий к вопросу  1. Какие причины (факто...  \
# 1            1  Комментарий к вопросу  1. Какие причины (факто...
# 2            2  Комментарий к вопросу  1. Какие причины (факто...
# 3            3  Комментарий к вопросу  1. Какие причины (факто...
# 4            4  Комментарий к вопросу  1. Какие причины (факто...
# 5            5  Комментарий к вопросу  1. Какие причины (факто...
# 6            6  Комментарий к вопросу  1. Какие причины (факто...
# 7            7  Комментарий к вопросу  1. Какие причины (факто...
# 8            8  Комментарий к вопросу  1. Какие причины (факто...
# 9            9  Комментарий к вопросу  1. Какие причины (факто...
# 10          10  Комментарий к вопросу  1. Какие причины (факто...
# 11          11  Комментарий к вопросу  1. Какие причины (факто...
# 12          12  Комментарий к вопросу  1. Какие причины (факто...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Функция для построения диаграммы с агрегацией "других" вариантов
def plot_question_responses(df, question, max_answers=7):
    # Фильтрация данных по вопросу
    question_data = df[df['Вопрос'] == question]
    
    # Сортировка по количеству ответов
    question_data = question_data.sort_values(by='Количество', ascending=False)
    
    # Если вариантов больше max_answers, агрегация оставшихся в "Другое"
    if len(question_data) > max_answers:
        top_responses = question_data.iloc[:max_answers]
        other_responses = question_data.iloc[max_answers:]
        # Добавляем суммарное количество для категории "Другое"
        other_sum = other_responses['Количество'].sum()
        other_row = pd.DataFrame({'Ответ': ['Другое'], 'Количество': [other_sum]})
        top_responses = pd.concat([top_responses, other_row], ignore_index=True)
    else:
        top_responses = question_data
    
    # Построение линейчатой диаграммы
    top_responses = top_responses.sort_values(by='Количество', ascending=True)
    plt.figure(figsize=(10, 6))
    plt.barh(top_responses['Ответ'], top_responses['Количество'], color='skyblue')
    plt.xlabel('Количество')
    plt.ylabel('Ответы')
    plt.title(f'Распределение ответов на вопрос: {question}')
    plt.show()

# Список уникальных вопросов
questions = df['Вопрос'].unique()

# Для каждого вопроса строим диаграмму
for question in questions:
    plot_question_responses(df, question)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Генерация примера данных с более чем 7 вариантами ответа для 5 вопросов
data = {
    'Вопрос': [
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?', 
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?', 
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?',
        'Как вы оцениваете условия работы?', 'Как вы оцениваете условия работы?',
        
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?', 
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?',
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?',
        'Как вы оцениваете коллектив?', 'Как вы оцениваете коллектив?',
        
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?',
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?',
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?',
        'Как оцениваете возможности роста?', 'Как оцениваете возможности роста?',
        
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?',
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?',
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?',
        'Насколько вам удобен график работы?', 'Насколько вам удобен график работы?',
        
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?',
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?',
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?',
        'Как оцениваете поддержку со стороны руководства?', 'Как оцениваете поддержку со стороны руководства?'
    ],
    'Ответ': [
        'Отлично', 'Хорошо', 'Плохо', 'Ужасно', 'Нейтрально', 'Не знаю', 'Отвратительно', 'Прекрасно',  # Вопрос 1
        'Дружный', 'Конфликтный', 'Поддерживающий', 'Хаотичный', 'Нейтральный', 'Токсичный', 'Разобщённый', 'Единый',  # Вопрос 2
        'Отличные перспективы', 'Нет перспектив', 'Маленькие перспективы', 'Средние возможности', 'Не знаю', 'Ужасные перспективы', 'Много возможностей', 'Никаких перспектив',  # Вопрос 3
        'Удобный', 'Неудобный', 'Гибкий', 'Нестабильный', 'Средний', 'Нейтральный', 'Не знаю', 'Отвратительный',  # Вопрос 4
        'Есть поддержка', 'Нет поддержки', 'Слабая поддержка', 'Сильная поддержка', 'Никакая поддержка', 'Мощная поддержка', 'Ужасная поддержка', 'Не знаю'  # Вопрос 5
    ],
    'Тип ответа': [
        'Позитивный', 'Позитивный', 'Негативный', 'Негативный', 'Нейтральный', 'Нейтральный', 'Негативный', 'Позитивный',  # Вопрос 1
        'Позитивный', 'Негативный', 'Позитивный', 'Негативный', 'Нейтральный', 'Негативный', 'Негативный', 'Позитивный',  # Вопрос 2
        'Позитивный', 'Негативный', 'Негативный', 'Нейтральный', 'Нейтральный', 'Негативный', 'Позитивный', 'Негативный',  # Вопрос 3
        'Позитивный', 'Негативный', 'Позитивный', 'Негативный', 'Нейтральный', 'Нейтральный', 'Нейтральный', 'Негативный',  # Вопрос 4
        'Позитивный', 'Негативный', 'Негативный', 'Позитивный', 'Негативный', 'Позитивный', 'Негативный', 'Нейтральный'  # Вопрос 5
    ],
    'Количество': [
        30, 40, 10, 5, 20, 10, 2, 25,  # Вопрос 1
        35, 15, 40, 10, 20, 5, 5, 30,  # Вопрос 2
        40, 10, 5, 15, 10, 3, 25, 7,  # Вопрос 3
        45, 10, 30, 15, 20, 5, 5, 10,  # Вопрос 4
        25, 20, 15, 30, 10, 35, 5, 8  # Вопрос 5
    ]
}

df = pd.DataFrame(data)

# Функция для построения круговых диаграмм по типу ответа
def plot_pie_chart_by_answer_type(df, question):
    # Фильтрация данных по вопросу
    question_data = df[df['Вопрос'] == question]
    
    # Группировка по типу ответа и суммирование количества
    type_summary = question_data.groupby('Тип ответа')['Количество'].sum()
    
    # Построение круговой диаграммы
    plt.figure(figsize=(6, 6))
    plt.pie(type_summary, labels=type_summary.index, autopct='%1.1f%%', startangle=90, colors=['red', 'gray', 'green'])
    plt.title(f'Распределение типов ответов: {question}')
    plt.show()

# Список уникальных вопросов
questions = df['Вопрос'].unique()

# Построение круговых диаграмм для каждого вопроса
for question in questions:
    plot_pie_chart_by_answer_type(df, question)
